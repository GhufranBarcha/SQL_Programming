# %% [markdown]
# # Will Use sqlite3 to established a connection to SQL server

# %%
import sqlite3

# %%
conn  = sqlite3.connect("INSTRUCTOR.db")

# %%
cursor_object = conn.cursor()

# %%
cursor_object.execute("DROP TABLE IF EXISTS INSTRUCTOR")

# %%
table = """ create table IF NOT EXISTS INSTRUCTOR(ID INTEGER PRIMARY KEY NOT NULL, FNAME VARCHAR(20), LNAME VARCHAR(20), CITY VARCHAR(20), CCODE CHAR(2));"""
 
cursor_object.execute(table)
 
print("Table is Ready")
# Out:
# Table is Ready

# %%
cursor_object.execute('''insert into INSTRUCTOR values (1, 'Rav', 'Ahuja', 'TORONTO', 'CA')''')

# %%
cursor_object.execute('''insert into INSTRUCTOR values (2, 'Raul', 'Chong', 'Markham', 'CA'), (3, 'Hima', 'Vasudevan', 'Chicago', 'US')''')

# %%
statement = '''SELECT * FROM INSTRUCTOR'''
cursor_object.execute(statement)

print("All the data")
output_all = cursor_object.fetchall()
for row_all in output_all:
  print(row_all)
# Out:
# All the data
# (1, 'Rav', 'Ahuja', 'TORONTO', 'CA')
# (2, 'Raul', 'Chong', 'Markham', 'CA')
# (3, 'Hima', 'Vasudevan', 'Chicago', 'US')

# %%
output_all
# Out:
# [(1, 'Rav', 'Ahuja', 'TORONTO', 'CA'),
#  (2, 'Raul', 'Chong', 'Markham', 'CA'),
#  (3, 'Hima', 'Vasudevan', 'Chicago', 'US')]

# %%
## Fetch few rows from the table
statement = '''SELECT * FROM INSTRUCTOR'''
cursor_object.execute(statement)
  
print("All the data")
# If you want to fetch few rows from the table we use fetchmany(numberofrows) and mention the number how many rows you want to fetch
output_many = cursor_object.fetchmany(2) 
for row_many in output_many:
  print(row_many)
# Out:
# All the data
# (1, 'Rav', 'Ahuja', 'TORONTO', 'CA')
# (2, 'Raul', 'Chong', 'Markham', 'CA')

# %%
# Fetch only FNAME from the table
statement = ''' SELECT FNAME FROM INSTRUCTOR '''
cursor_object.execute(statement)
output = cursor_object.fetchall()
output
# Out:
# [('Rav',), ('Raul',), ('Hima',)]

# %%
query = ''' UPDATE INSTRUCTOR SET CITY = "MOSETOWN"  WHERE FNAME = "Rav"'''
cursor_object.execute(query)

# %%
statement = ''' SELECT * FROM INSTRUCTOR '''
cursor_object.execute(statement)
output = cursor_object.fetchall()
output
# Out:
# [(1, 'Rav', 'Ahuja', 'MOSETOWN', 'CA'),
#  (2, 'Raul', 'Chong', 'Markham', 'CA'),
#  (3, 'Hima', 'Vasudevan', 'Chicago', 'US')]

# %%
import pandas as pd
#retrieve the query results into a pandas dataframe
df = pd.read_sql_query("select * from instructor;", conn ,)

#print the dataframe
df
# Out:
#    ID FNAME      LNAME      CITY CCODE
# 0   1   Rav      Ahuja  MOSETOWN    CA
# 1   2  Raul      Chong   Markham    CA
# 2   3  Hima  Vasudevan   Chicago    US

# %%
df.LNAME[0]
# Out:
# 'Ahuja'

# %%
df.shape
# Out:
# (3, 5)

# %%
# Close the connection
conn.close()

# %%
# These libraries are pre-installed in SN Labs. If running in another environment please uncomment lines below to install them:
#!pip install --force-reinstall ibm_db==3.1.0 ibm_db_sa==0.3.3
# Ensure we don't load_ext with sqlalchemy>=1.4 (incompadible)
#!pip uninstall sqlalchemy==1.4 -y && pip install sqlalchemy==1.3.24
#!pip install ipython-sql
# Out:
# Collecting ibm_db==3.1.0
#   Using cached ibm_db-3.1.0.tar.gz (797 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting ibm_db_sa==0.3.3
#   Using cached ibm_db_sa-0.3.3-py3-none-any.whl
# Collecting sqlalchemy>=0.7.3
#   Using cached SQLAlchemy-2.0.19-cp310-cp310-win_amd64.whl (2.0 MB)
# Collecting typing-extensions>=4.2.0
#   Using cached typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting greenlet!=0.4.17
#   Using cached greenlet-2.0.2-cp310-cp310-win_amd64.whl (192 kB)
# Building wheels for collected packages: ibm_db
#   Building wheel for ibm_db (pyproject.toml): started
#   Building wheel for ibm_db (pyproject.toml): finished with status 'error'
# Failed to build ibm_db
#   error: subprocess-exited-with-error
#
#   Building wheel for ibm_db (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [1106 lines of output]
#   Detected 64-bit Python
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-310
#   copying ibm_db_dbi.py -> build\lib.win-amd64-cpython-310
#   copying testfunctions.py -> build\lib.win-amd64-cpython-310
#   copying tests.py -> build\lib.win-amd64-cpython-310
#   creating build\lib.win-amd64-cpython-310\certs
#   copying certs\__init__.py -> build\lib.win-amd64-cpython-310\certs
#   creating build\lib.win-amd64-cpython-310\clidriver
#   copying clidriver\__init__.py -> build\lib.win-amd64-cpython-310\clidriver
#   creating build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_000_PrepareDb.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_001_ConnDb.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_002_ConnDbUncatalogedConn.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_003_NumAffectedRows.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_004_ConnWrongUserPwd.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_005_ConnBadUserBadPwd.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_006_ConnPassingOpts.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_007_pConnPassingOpts.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_008_ColumnInfo.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_010_UpdateRowCount.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_011_DeleteRowCount.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_012_KeysetDrivenCursorSelect01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_013_KeysetDrivenCursorSelect02.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_014_KeysetDrivenCursorNegativeRow.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_015_InsertDeleteRowCount_01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_016_InsertDeleteRowCount_02.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_017_selectRowcountPrefetchSTMTOpt.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_018_selectRowcountPrefetchSetOpt.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_019_selectRowcountPrefetchPrepOpt.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_020_RollbackDelete.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_021_CommitDelete.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_022_RollbackInsert.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_023_ColumnPrivileges.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_024_ForeignKeys.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_025_PrimaryKeys.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_030_Result.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_031_ResultIndexPosition.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_032_ResultIndexName.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_033_ResultOutSequenceColumn.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_034_FetchAssoc.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_035_FetchRow_01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_036_FetchRow_02.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_037_FetchRowIndexPos.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_038_FetchRowIndexPosNested_01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_039_FetchRowIndexPosNested_02.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_03a_ResultNonExistCol.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_040_FetchTuple.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_041_FetchTupleMany_01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_042_FetchTupleMany_02.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_043_FetchTupleMany_03.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_044_FetchTupleMany_04.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_045_FetchTupleBinaryData_01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_046_FetchTupleMany_05.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_047_FetchTupleMany_06.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_048_FetchTupleBinaryData_02.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_049_InsertNoneParam.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_050_AutocommitStatus.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_051_SetAutocommit_01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_052_SetAutocommit_02.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_053_AttrThruConn.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_054_CursorType.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_060_Tables_01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_061_Tables_02.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_062_Tables_03.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_063_Tables_04.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_064_Tables_05.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_065_FilterTableName.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_066_TableObjects.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_070_Close.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_071_CloseSuccess.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_080_ConnWrongDbAlias.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_081_ConnWrongUser.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_082_ConnWrongPwd.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_090_ConnmsgWrongDbAlias.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_091_ConnmsgWrongUser.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_092_ConnmsgWrongPwd.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_100_SelectDeleteInsertFieldCount.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_101_InsertDeleteFieldCount.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_102_NumFieldsSelect_01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_103_NumFieldsSelect_02.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_110_FieldNum.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_111_FieldNumAddCol.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_112_FieldNumDiffCaseColNames.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_113_DateTest.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_114_NumericTest_01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_115_NumericTest_02.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_116_ConnActive.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_120_FieldName.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_121_FieldNameAddCol.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_122_FieldNameDiffCaseColNames.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_123_FieldNamePos_01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_124_FieldNamePos_02.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_125_FieldNamePos_03.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_130_PrepExecuteSelectStmt.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_131_PrepareExecuteSelectStatementParams.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_132_ExecuteStatementArrayMultipleParams.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_133_ExecuteLongInputParams.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_140_BindParamSelectStmt.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_141_BindParamSelectStmtMultipleParams_01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_142_BindParamSelectStmtMultipleParams_02.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_143_BindParamInsertStmtNoneParam.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_144_BindParamInsertStmtPARAM_FILE.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_145_BindRetrieveNoneEmptyString.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_146_CallSPINAndOUTParams.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_147_PrepareWithWrongType.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_148_CallSPDiffBindPattern_01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_150_FetchAssocSelect_01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_151_FetchAssocSelect_02.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_152_FetchAssocSelect_03.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_153_FetchAssocSelect_04.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_154_AllFetches.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_155_FetchAssocSelect_05.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_156_FetchAssocNestedSelects_01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_157a_FetchAssocWithoutScrollableCursorErr.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_157b_FetchAssocScrollableCursor_02.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_157_FetchAssocScrollableCursor_01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_158_FetchAssocNestedSelects_02.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_159a_FetchAssocSeveralRows_02.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_159_FetchAssocSeveralRows_01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_160_FetchBoth.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_161_FetchBothNestedSelects_01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_162_FetchBothNestedSelects_02.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_180_StmtErrMsg.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_190_ColumnsTable_01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_191_ColumnsTable_02.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_195_InsertRetrieveXMLData_01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_196_InsertRetrieveXMLData_02.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_197_StatisticsIndexes.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_200_MultipleRsltsetsUniformColDefs.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_201_MultipleRsltsetsDiffColDefs.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_210_FieldDisplaySize_01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_211_FieldDisplaySize_02.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_212_FieldDisplaySize_03.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_213_FieldDisplaySize_04.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_220_PersistentConn.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_221_100PersistentConns.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_230_FieldTypePos.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_231_FieldTypeName.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_232_FieldTypePosName.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_240_FieldWidthPosName_01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_241_FieldWidthPosName_02.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_250_FreeResult_01.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_251_FreeResult_02.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_260_FetchTupleMany_07.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_261_FetchObjectAccess.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_264_InsertRetrieveBIGINTTypeColumn.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_265_NoAffectedRows.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_300_ServerInfo.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_310_ClientInfo.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_311_InsertSelectDeleteNumLiterals.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_52949_TestSPIntVarcharXml.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_6528_ScopingProblemBindParam.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_6561_InsertNULLValues.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_6755_ExtraNULLChar_ResultCLOBCol.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_6792_FieldTypeRetStrDatetimeTimestamp.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_booleanInsertSelect.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_bool_callproc.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_checkBooleanType.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_createdbNX.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_createDropDB.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_currentschema.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_cursortype.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_decfloat.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_decimal.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_err_executemany.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_execute_many.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_InsertRetrieveDateTimeTypeColumn.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_recreateDB.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_setgetOption.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_SPInOutBlob.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_SPInOutZero.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_trusted_context_connect.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_trusted_context_pconnect.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\test_warn.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   copying ibm_db_tests\__init__.py -> build\lib.win-amd64-cpython-310\ibm_db_tests
#   running egg_info
#   writing ibm_db.egg-info\PKG-INFO
#   writing dependency_links to ibm_db.egg-info\dependency_links.txt
#   writing top-level names to ibm_db.egg-info\top_level.txt
#   reading manifest file 'ibm_db.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching '*.png' under directory 'ibm_db_tests'
#   warning: no files found matching '*.jpg' under directory 'ibm_db_tests'
#   warning: no files found matching '*' under directory 'ibm_db_dlls'
#   warning: no previously-included files found matching 'config.py'
#   adding license file 'LICENSE'
#   writing manifest file 'ibm_db.egg-info\SOURCES.txt'
#   C:\Users\Barcha\AppData\Local\Temp\pip-build-env-g6zm2ux9\overlay\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'clidriver.bin' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'clidriver.bin' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'clidriver.bin' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'clidriver.bin' to be distributed and are
#           already explicitly excluding 'clidriver.bin' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Barcha\AppData\Local\Temp\pip-build-env-g6zm2ux9\overlay\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'clidriver.bin.icc64' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'clidriver.bin.icc64' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'clidriver.bin.icc64' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'clidriver.bin.icc64' to be distributed and are
#           already explicitly excluding 'clidriver.bin.icc64' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Barcha\AppData\Local\Temp\pip-build-env-g6zm2ux9\overlay\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'clidriver.bin.icc64.c.icc' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'clidriver.bin.icc64.c.icc' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'clidriver.bin.icc64.c.icc' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'clidriver.bin.icc64.c.icc' to be distributed and are
#           already explicitly excluding 'clidriver.bin.icc64.c.icc' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Barcha\AppData\Local\Temp\pip-build-env-g6zm2ux9\overlay\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'clidriver.bin.icc64.c.icc.icclib' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'clidriver.bin.icc64.c.icc.icclib' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'clidriver.bin.icc64.c.icc.icclib' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'clidriver.bin.icc64.c.icc.icclib' to be distributed and are
#           already explicitly excluding 'clidriver.bin.icc64.c.icc.icclib' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Barcha\AppData\Local\Temp\pip-build-env-g6zm2ux9\overlay\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'clidriver.bin.icc64.n.icc' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'clidriver.bin.icc64.n.icc' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'clidriver.bin.icc64.n.icc' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'clidriver.bin.icc64.n.icc' to be distributed and are
#           already explicitly excluding 'clidriver.bin.icc64.n.icc' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Barcha\AppData\Local\Temp\pip-build-env-g6zm2ux9\overlay\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'clidriver.bin.icc64.n.icc.icclib' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'clidriver.bin.icc64.n.icc.icclib' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'clidriver.bin.icc64.n.icc.icclib' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'clidriver.bin.icc64.n.icc.icclib' to be distributed and are
#           already explicitly excluding 'clidriver.bin.icc64.n.icc.icclib' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Barcha\AppData\Local\Temp\pip-build-env-g6zm2ux9\overlay\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'clidriver.bnd' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'clidriver.bnd' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'clidriver.bnd' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'clidriver.bnd' to be distributed and are
#           already explicitly excluding 'clidriver.bnd' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Barcha\AppData\Local\Temp\pip-build-env-g6zm2ux9\overlay\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'clidriver.cfg' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'clidriver.cfg' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'clidriver.cfg' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'clidriver.cfg' to be distributed and are
#           already explicitly excluding 'clidriver.cfg' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Barcha\AppData\Local\Temp\pip-build-env-g6zm2ux9\overlay\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'clidriver.conv.alt' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'clidriver.conv.alt' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'clidriver.conv.alt' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'clidriver.conv.alt' to be distributed and are
#           already explicitly excluding 'clidriver.conv.alt' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Barcha\AppData\Local\Temp\pip-build-env-g6zm2ux9\overlay\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'clidriver.conv.ms' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'clidriver.conv.ms' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'clidriver.conv.ms' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'clidriver.conv.ms' to be distributed and are
#           already explicitly excluding 'clidriver.conv.ms' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Barcha\AppData\Local\Temp\pip-build-env-g6zm2ux9\overlay\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'clidriver.db2' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'clidriver.db2' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'clidriver.db2' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'clidriver.db2' to be distributed and are
#           already explicitly excluding 'clidriver.db2' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Barcha\AppData\Local\Temp\pip-build-env-g6zm2ux9\overlay\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'clidriver.include' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'clidriver.include' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'clidriver.include' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'clidriver.include' to be distributed and are
#           already explicitly excluding 'clidriver.include' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Barcha\AppData\Local\Temp\pip-build-env-g6zm2ux9\overlay\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'clidriver.lib' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'clidriver.lib' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'clidriver.lib' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'clidriver.lib' to be distributed and are
#           already explicitly excluding 'clidriver.lib' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Barcha\AppData\Local\Temp\pip-build-env-g6zm2ux9\overlay\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'clidriver.license' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
# ...
#   creating build\lib.win-amd64-cpython-310\clidriver\bin\icc64\c
#   creating build\lib.win-amd64-cpython-310\clidriver\bin\icc64\c\icc
#   copying clidriver\bin\icc64\c\icc\ReadMe.txt -> build\lib.win-amd64-cpython-310\clidriver\bin\icc64\c\icc
#   creating build\lib.win-amd64-cpython-310\clidriver\bin\icc64\c\icc\icclib
#   copying clidriver\bin\icc64\c\icc\icclib\ICCSIG.txt -> build\lib.win-amd64-cpython-310\clidriver\bin\icc64\c\icc\icclib
#   copying clidriver\bin\icc64\c\icc\icclib\icclib084.dll -> build\lib.win-amd64-cpython-310\clidriver\bin\icc64\c\icc\icclib
#   creating build\lib.win-amd64-cpython-310\clidriver\bin\icc64\n
#   creating build\lib.win-amd64-cpython-310\clidriver\bin\icc64\n\icc
#   copying clidriver\bin\icc64\n\icc\ReadMe.txt -> build\lib.win-amd64-cpython-310\clidriver\bin\icc64\n\icc
#   creating build\lib.win-amd64-cpython-310\clidriver\bin\icc64\n\icc\icclib
#   copying clidriver\bin\icc64\n\icc\icclib\ICCSIG.txt -> build\lib.win-amd64-cpython-310\clidriver\bin\icc64\n\icc\icclib
#   copying clidriver\bin\icc64\n\icc\icclib\icclib085.dll -> build\lib.win-amd64-cpython-310\clidriver\bin\icc64\n\icc\icclib
#   creating build\lib.win-amd64-cpython-310\clidriver\bnd
#   copying clidriver\bnd\db2ajgrt.bnd -> build\lib.win-amd64-cpython-310\clidriver\bnd
#   copying clidriver\bnd\db2cli.bnd -> build\lib.win-amd64-cpython-310\clidriver\bnd
#   copying clidriver\bnd\db2cli.lst -> build\lib.win-amd64-cpython-310\clidriver\bnd
#   copying clidriver\bnd\db2clipk.bnd -> build\lib.win-amd64-cpython-310\clidriver\bnd
#   copying clidriver\bnd\db2clist.bnd -> build\lib.win-amd64-cpython-310\clidriver\bnd
#   copying clidriver\bnd\db2spcdb.bnd -> build\lib.win-amd64-cpython-310\clidriver\bnd
#   creating build\lib.win-amd64-cpython-310\clidriver\cfg
#   copying clidriver\cfg\DigiCertGlobalRootCA.arm -> build\lib.win-amd64-cpython-310\clidriver\cfg
#   copying clidriver\cfg\db2dsdriver.xsd -> build\lib.win-amd64-cpython-310\clidriver\cfg
#   creating build\lib.win-amd64-cpython-310\clidriver\conv
#   creating build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\04370923.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\08500923.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\08501252.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\08600923.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\08630923.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\09230437.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\09230850.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\09230860.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\09231043.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\09231051.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\09231114.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\09231208.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\09231252.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\09231275.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\09241252.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\09370950.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\10430923.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\10510923.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\11140923.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\12080923.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\12520850.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\12520923.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\12750923.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\1388ucs2.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\IBM00850.ucs -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\IBM00923.ucs -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   copying clidriver\conv\alt\IBM01252.ucs -> build\lib.win-amd64-cpython-310\clidriver\conv\alt
#   creating build\lib.win-amd64-cpython-310\clidriver\conv\ms
#   copying clidriver\conv\ms\0930ucs2.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\ms
#   copying clidriver\conv\ms\0939ucs2.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\ms
#   copying clidriver\conv\ms\0943ucs2.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\ms
#   copying clidriver\conv\ms\0954ucs2.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\ms
#   copying clidriver\conv\ms\1390ucs2.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\ms
#   copying clidriver\conv\ms\1399ucs2.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\ms
#   copying clidriver\conv\ms\5039ucs2.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\ms
#   copying clidriver\conv\ms\ucs20943.cnv -> build\lib.win-amd64-cpython-310\clidriver\conv\ms
#   creating build\lib.win-amd64-cpython-310\clidriver\db2
#   copying clidriver\db2\db2diag.log -> build\lib.win-amd64-cpython-310\clidriver\db2
#   creating build\lib.win-amd64-cpython-310\clidriver\include
#   copying clidriver\include\sql.h -> build\lib.win-amd64-cpython-310\clidriver\include
#   copying clidriver\include\sqlca.h -> build\lib.win-amd64-cpython-310\clidriver\include
#   copying clidriver\include\sqlcli.h -> build\lib.win-amd64-cpython-310\clidriver\include
#   copying clidriver\include\sqlcli1.h -> build\lib.win-amd64-cpython-310\clidriver\include
#   copying clidriver\include\sqlda.h -> build\lib.win-amd64-cpython-310\clidriver\include
#   copying clidriver\include\sqlenv.h -> build\lib.win-amd64-cpython-310\clidriver\include
#   copying clidriver\include\sqlext.h -> build\lib.win-amd64-cpython-310\clidriver\include
#   copying clidriver\include\sqlstate.h -> build\lib.win-amd64-cpython-310\clidriver\include
#   copying clidriver\include\sqlsystm.h -> build\lib.win-amd64-cpython-310\clidriver\include
#   copying clidriver\include\sqltypes.h -> build\lib.win-amd64-cpython-310\clidriver\include
#   copying clidriver\include\sqlucode.h -> build\lib.win-amd64-cpython-310\clidriver\include
#   copying clidriver\include\sqlunx.h -> build\lib.win-amd64-cpython-310\clidriver\include
#   creating build\lib.win-amd64-cpython-310\clidriver\lib
#   copying clidriver\lib\db2app64.lib -> build\lib.win-amd64-cpython-310\clidriver\lib
#   copying clidriver\lib\db2cli64.lib -> build\lib.win-amd64-cpython-310\clidriver\lib
#   creating build\lib.win-amd64-cpython-310\clidriver\license
#   copying clidriver\license\odbc_REDIST.txt -> build\lib.win-amd64-cpython-310\clidriver\license
#   copying clidriver\license\odbc_notices.rtf -> build\lib.win-amd64-cpython-310\clidriver\license
#   creating build\lib.win-amd64-cpython-310\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_br.rtf -> build\lib.win-amd64-cpython-310\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_cn.rtf -> build\lib.win-amd64-cpython-310\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_cz.rtf -> build\lib.win-amd64-cpython-310\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_de.rtf -> build\lib.win-amd64-cpython-310\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_el.rtf -> build\lib.win-amd64-cpython-310\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_en.rtf -> build\lib.win-amd64-cpython-310\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_es.rtf -> build\lib.win-amd64-cpython-310\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_fr.rtf -> build\lib.win-amd64-cpython-310\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_in.rtf -> build\lib.win-amd64-cpython-310\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_it.rtf -> build\lib.win-amd64-cpython-310\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_jp.rtf -> build\lib.win-amd64-cpython-310\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_kr.rtf -> build\lib.win-amd64-cpython-310\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_lt.rtf -> build\lib.win-amd64-cpython-310\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_pl.rtf -> build\lib.win-amd64-cpython-310\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_ru.rtf -> build\lib.win-amd64-cpython-310\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_sl.rtf -> build\lib.win-amd64-cpython-310\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_tr.rtf -> build\lib.win-amd64-cpython-310\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_tw.rtf -> build\lib.win-amd64-cpython-310\clidriver\license\Windows
#   creating build\lib.win-amd64-cpython-310\clidriver\msg
#   creating build\lib.win-amd64-cpython-310\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2adm.mo -> build\lib.win-amd64-cpython-310\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2admh.mo -> build\lib.win-amd64-cpython-310\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2caem.mo -> build\lib.win-amd64-cpython-310\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2cklog.mo -> build\lib.win-amd64-cpython-310\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2cli.mo -> build\lib.win-amd64-cpython-310\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clia1.lst -> build\lib.win-amd64-cpython-310\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clias.lst -> build\lib.win-amd64-cpython-310\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clih.mo -> build\lib.win-amd64-cpython-310\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clit.mo -> build\lib.win-amd64-cpython-310\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clp.mo -> build\lib.win-amd64-cpython-310\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clp2.mo -> build\lib.win-amd64-cpython-310\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2fodc.mo -> build\lib.win-amd64-cpython-310\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2sql.mo -> build\lib.win-amd64-cpython-310\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2sqlh.mo -> build\lib.win-amd64-cpython-310\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2stt.mo -> build\lib.win-amd64-cpython-310\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2supp.mo -> build\lib.win-amd64-cpython-310\clidriver\msg\en_US
#   creating build\lib.win-amd64-cpython-310\clidriver\properties
#   creating build\lib.win-amd64-cpython-310\clidriver\properties\version
#   copying clidriver\properties\version\ibm.com_IBM_Data_Server_Driver_for_ODBC_and_CLI-11.5.0.swidtag -> build\lib.win-amd64-cpython-310\clidriver\properties\version
#   creating build\lib.win-amd64-cpython-310\clidriver\security
#   creating build\lib.win-amd64-cpython-310\clidriver\security\plugin
#   creating build\lib.win-amd64-cpython-310\clidriver\security\plugin\IBM
#   creating build\lib.win-amd64-cpython-310\clidriver\security\plugin\IBM\client
#   copying clidriver\security\plugin\IBM\client\IBMIAMauth64.dll -> build\lib.win-amd64-cpython-310\clidriver\security\plugin\IBM\client
#   running build_ext
#   building 'ibm_db' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for ibm_db
# ERROR: Could not build wheels for ibm_db, which is required to install pyproject.toml-based projects
# Found existing installation: SQLAlchemy 2.0.19
# Uninstalling SQLAlchemy-2.0.19:
#   Successfully uninstalled SQLAlchemy-2.0.19
# Collecting sqlalchemy==1.3.24
#   Using cached SQLAlchemy-1.3.24-cp310-cp310-win_amd64.whl
# Installing collected packages: sqlalchemy
# Successfully installed sqlalchemy-1.3.24
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.3.24 which is incompatible.
# Requirement already satisfied: ipython-sql in c:\users\barcha\anaconda\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\barcha\anaconda\lib\site-packages (from ipython-sql) (3.8.0)
# Requirement already satisfied: six in c:\users\barcha\anaconda\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: sqlparse in c:\users\barcha\anaconda\lib\site-packages (from ipython-sql) (0.4.4)
# Collecting sqlalchemy>=2.0
#   Using cached SQLAlchemy-2.0.19-cp310-cp310-win_amd64.whl (2.0 MB)
# Requirement already satisfied: ipython-genutils in c:\users\barcha\anaconda\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: ipython in c:\users\barcha\anaconda\lib\site-packages (from ipython-sql) (8.10.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\barcha\anaconda\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.4.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\barcha\anaconda\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (2.0.1)
# Requirement already satisfied: pickleshare in c:\users\barcha\anaconda\lib\site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\barcha\anaconda\lib\site-packages (from ipython->ipython-sql) (2.11.2)
# Requirement already satisfied: colorama in c:\users\barcha\anaconda\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator in c:\users\barcha\anaconda\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: traitlets>=5 in c:\users\barcha\anaconda\lib\site-packages (from ipython->ipython-sql) (5.7.1)
# Requirement already satisfied: matplotlib-inline in c:\users\barcha\anaconda\lib\site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: jedi>=0.16 in c:\users\barcha\anaconda\lib\site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\barcha\anaconda\lib\site-packages (from ipython->ipython-sql) (3.0.36)
# Requirement already satisfied: stack-data in c:\users\barcha\anaconda\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: backcall in c:\users\barcha\anaconda\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: wcwidth in c:\users\barcha\anaconda\lib\site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\barcha\anaconda\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\barcha\anaconda\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\barcha\anaconda\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: executing in c:\users\barcha\anaconda\lib\site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Installing collected packages: sqlalchemy
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.3.24
#     Uninstalling SQLAlchemy-1.3.24:
#       Successfully uninstalled SQLAlchemy-1.3.24
# Successfully installed sqlalchemy-2.0.19

# %%
## To load sql in
# %load_ext sql

# %%
import csv ,sqlite3

con = sqlite3.connect("SQLITEmAGIC")
